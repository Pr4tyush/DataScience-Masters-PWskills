# %%
import bokeh.io 
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1001">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure,output_file,show
from bokeh.sampledata.iris import flowers

output_file("test.html")
p = figure(title = "test Flower")
p.xaxis.axis_label = "petel length"
p.yaxis.axis_label = "petel weith"
p.circle(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div id="01bc4e56-1af2-4710-86a0-a06c10e6419f" data-root-id="p1297" style="display: contents;"></div>

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
from bokeh.plotting import figure,output_file,show
from bokeh.sampledata.iris import flowers

output_file("test.html")
p = figure(title = "test Flower")
p.xaxis.axis_label = "petel length"
p.yaxis.axis_label = "petel weith"
p.line(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div id="949efeeb-746b-4562-9b03-afd3c772386f" data-root-id="p1984" style="display: contents;"></div>
